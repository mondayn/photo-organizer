# %%
# curating some target faces
from fx import *

# %%
wife=[
    get_encodings(i) for i in ['labeled_pics/wife.JPG']
]
save_encodings("labeled_embeddings/wife.npz",wife)

# %%
daughter=[
    get_encodings(i) for i in [
        'labeled_pics/daughter.JPG',  
        'labeled_pics/daughter1.JPG', 
    ]
]
save_encodings("labeled_embeddings/daughter.npz",daughter)

# wow, works over time
compare_faces(
    daughter[0],        # at ~ 18 months
    daughter[1][0]      # at 3 yrs
)
# Out:
# [True]

# %%
# thank goodness
compare_faces(daughter[0],wife[0][0])
# Out:
# [False]

# %%
me = [
    get_encodings(i) for i in [
        'labeled_pics/me.JPG',
    ]
]
save_encodings("labeled_embeddings/me.npz",me)

compare_faces(me[0],wife[0][0])
# Out:
# [False]
